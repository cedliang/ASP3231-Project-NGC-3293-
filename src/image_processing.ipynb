# %% [markdown]
# # Image Processing

# %% [markdown]
# Import the relevant libraries.

# %%
import numpy as np
import astropy
import ccdproc
from ccdproc import CCDData, combiner
from astropy import units as u
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load in the median combined bias, dark, and flats for each band.

# %%
bias_median = CCDData.read('bias_median.fits', unit = 'adu')
dark_median = CCDData.read('dark_median.fits', unit = 'adu')
Rflat_median = CCDData.read('flat_R_median.fits', unit = 'adu')
Vflat_median = CCDData.read('flat_V_median.fits', unit = 'adu')
Bflat_median = CCDData.read('flat_B_median.fits', unit = 'adu')
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu2 in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu2 in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu2 in the FITS file. [astropy.nddata.ccddata]

# %% [markdown]
# Now we process the science images using the bias, dark and the relevant flat. The following function will do this for us, and save the image with the 'proc_' prefix at the start of the file name.

# %%
def process_scims(sci_images, dark, bias, flat, directory):
    # read the science images and save them to a list
    scim = [CCDData.read(directory + '/' + fn, unit = "adu") for fn in sci_images.files_filtered(PICTTYPE = 1)]
    
    print('Processing', len(scim), 'science images')

    # print the counts (in adu) of the first science image
    print(scim[0])

    # subtract bias from each image
    for idx, thisimage in enumerate(scim): 
        scim[idx] = ccdproc.subtract_bias(thisimage, bias)
        
    print('Counts of first column of first science image after bias subtraction')
    print(scim[0][0,:])

    # subtract dark from each image
    for idx, thisimage in enumerate(scim): 
        scim[idx] = ccdproc.subtract_dark(thisimage, dark, exposure_time = 'EXPTIME', 
                                          exposure_unit = u.second, scale = True)
        
    print('Counts of first column of first science image after dark subtraction')
    print(scim[0][0,:])

    # divide by flat for each image
    for idx, thisimage in enumerate(scim): 
        scim[idx] = ccdproc.flat_correct(thisimage, flat)
        
    print('Counts of first column of first science image after division by flat')
    print(scim[0][0,:])

    
    # Write these images to output files. 
    # We added the proc prefix so we can tell the processed images apart from the raw images. 
    newname = []
    for fn in sci_images.files_filtered(PICTTYPE = 1):
        newname.extend(["proc_" + fn])

    # This image writes the science images out (while including some extra lines to reduce the file size)
    for idx, thisimage in enumerate(scim):
        tempimages = [thisimage]
        temp = ccdproc.Combiner(tempimages,dtype=np.float32).median_combine() 
        temp.meta = thisimage.meta
        temp.write(newname[idx])      # write image with new name to file

# %%
directory = 'C11_2022_03_28/'

# %%
# load images with '_R_' somewhere in the filename so that we only load in the R-band images
R_images = ccdproc.ImageFileCollection("./" + directory,glob_include = '*_R_*')
process_scims(R_images, dark_median, bias_median, Rflat_median, directory)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392529 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392529 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -4130881.901 from OBSGEO-[LBH].
# Set OBSGEO-Y to  2896022.315 from OBSGEO-[LBH].
# Set OBSGEO-Z to -3889419.901 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -4130881.901 from OBSGEO-[LBH].
# Set OBSGEO-Y to  2896022.315 from OBSGEO-[LBH].
# Set OBSGEO-Z to -3889419.901 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392602 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392602 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392675 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392675 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392748 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392748 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392820 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392820 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392893 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392893 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392966 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392966 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.393039 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.393039 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.393111 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.393111 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.393184 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.393184 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.411543 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.411543 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.412253 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.412253 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.412962 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.412962 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.413671 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.413671 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.414380 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.414380 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.415090 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.415090 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.415799 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.415799 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.416508 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.416508 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.417218 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.417218 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.417927 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.417927 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.435038 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.435038 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.435747 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.435747 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.439329 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.439329 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.440038 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.440038 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.446235 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.446235 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.446945 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.446945 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.447655 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.447655 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.448365 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.448365 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.451041 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.451041 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.451750 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.451750 from DATE-OBS'.
# Processing 30 science images
# [[2380 2341 2328 ... 2187 2132 2234]
#  [2334 2384 2278 ... 2207 2203 2205]
#  [2354 2373 2370 ... 2196 2205 2201]
#  ...
#  [2256 2307 2277 ... 2125 2228 2181]
#  [2276 2191 2311 ... 2184 2146 2202]
#  [2274 2241 2239 ... 2172 2167 2187]] adu
# Counts of first column of first science image after bias subtraction
# [230.  198.  188.5 ...  63.   11.  107. ] adu
# Counts of first column of first science image after dark subtraction
# [229.03263885 197.06041664 187.62430555 ...  62.61666664  10.71041664
#  106.70277777] adu
# Counts of first column of first science image after division by flat
# [228.7578657  198.06883458 188.62871212 ...  94.56855616  16.17347891
#  161.34194771] adu

# %%
# load images with '_V_' somewhere in the filename so that we only load in the V-band images
V_images = ccdproc.ImageFileCollection("./" + directory,glob_include = '*_V_*')
process_scims(V_images, dark_median, bias_median, Vflat_median, directory)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391572 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391572 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -4130881.901 from OBSGEO-[LBH].
# Set OBSGEO-Y to  2896022.315 from OBSGEO-[LBH].
# Set OBSGEO-Z to -3889419.901 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -4130881.901 from OBSGEO-[LBH].
# Set OBSGEO-Y to  2896022.315 from OBSGEO-[LBH].
# Set OBSGEO-Z to -3889419.901 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391645 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391645 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391718 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391718 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391790 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391790 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391863 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391863 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391936 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.391936 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392009 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392009 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392081 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392081 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392154 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392154 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392227 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.392227 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.403886 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.403886 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.404595 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.404595 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.405305 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.405305 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.406014 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.406014 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.406724 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.406724 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.407433 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.407433 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.408143 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.408143 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.408852 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.408852 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.409562 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.409562 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.410272 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.410272 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.432680 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.432680 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.433390 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.433390 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.437808 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.437808 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.438517 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.438517 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.441021 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.441021 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.441730 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.441730 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.442440 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.442440 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.443149 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.443149 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.449458 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.449458 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.450167 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.450167 from DATE-OBS'.
# Processing 30 science images
# [[2384 2410 2406 ... 2294 2158 2289]
#  [2352 2396 2410 ... 2278 2273 2247]
#  [2398 2358 2337 ... 2232 2259 2212]
#  ...
#  [2327 2171 2250 ... 2261 2260 2238]
#  [2256 2279 2334 ... 2246 2238 2332]
#  [2316 2285 2323 ... 2196 2290 2215]] adu
# Counts of first column of first science image after bias subtraction
# [234.  267.  266.5 ... 170.   37.  162. ] adu
# Counts of first column of first science image after dark subtraction
# [233.03263885 266.06041664 265.62430555 ... 169.61666664  36.71041664
#  161.70277777] adu
# Counts of first column of first science image after division by flat
# [230.4115812  264.56576625 263.50644901 ... 185.24799774  40.09691441
#  177.24414328] adu

# %%
# load images with '_B_' somewhere in the filename so that we only load in the B-band images
B_images = ccdproc.ImageFileCollection("./" + directory,glob_include = '*_B_*')
process_scims(B_images, dark_median, bias_median, Bflat_median, directory)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386313 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386313 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -4130881.901 from OBSGEO-[LBH].
# Set OBSGEO-Y to  2896022.315 from OBSGEO-[LBH].
# Set OBSGEO-Z to -3889419.901 from OBSGEO-[LBH]'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-X to -4130881.901 from OBSGEO-[LBH].
# Set OBSGEO-Y to  2896022.315 from OBSGEO-[LBH].
# Set OBSGEO-Z to -3889419.901 from OBSGEO-[LBH]'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386386 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386386 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386460 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386460 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386534 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386534 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386608 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386608 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386682 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386682 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386754 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386754 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386827 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386827 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386900 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386900 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386973 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.386973 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390217 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390217 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390290 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390290 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390364 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390364 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390437 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390437 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390510 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390510 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390583 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390583 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390655 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390655 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390728 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390728 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390801 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390801 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390873 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.390873 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.394409 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.394409 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.395119 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.395119 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.395828 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.395828 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.396537 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.396537 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.397247 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.397247 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.397956 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.397956 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.398665 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.398665 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.399375 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.399375 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.400084 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.400084 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.400794 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.400794 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.421674 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.421674 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.422384 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.422384 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.423094 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.423094 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.423803 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.423803 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.424513 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.424513 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.425222 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.425222 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.425931 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.425931 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.426641 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.426641 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.427350 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.427350 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.428059 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59666.428059 from DATE-OBS'.
# Processing 40 science images
# [[2336 2278 2314 ... 2173 2187 2164]
#  [2300 2274 2279 ... 2135 2268 2161]
#  [2326 2338 2360 ... 2218 2163 2169]
#  ...
#  [2208 2210 2178 ... 2169 2174 2270]
#  [2211 2206 2190 ... 2165 2278 2096]
#  [2222 2206 2211 ... 2135 2186 2219]] adu
# Counts of first column of first science image after bias subtraction
# [186.  135.  174.5 ...  49.   66.   37. ] adu
# Counts of first column of first science image after dark subtraction
# [185.03263885 134.06041664 173.62430555 ...  48.61666664  65.71041664
#   36.70277777] adu
# Counts of first column of first science image after division by flat
# [188.3735227  136.00562796 175.79946718 ...  57.87903529  78.68267665
#   44.24397481] adu

# %% [markdown]
# All of the statistics look good. The counts reduce by about 2100 when we subtract the bias, which makes sense since the median of the bias was around 2100. The counts reduce by about 1 when we subtract the dark, which makes sense given the scaling between the exposure time of the dark and the science images. This is independent of the band, which is as expected since the bias and dark are independent of the filter that we use.
#
# We also examined some images in ds9 in each of the bands and found that dust donuts that were visible in the unprocessed science images were removed in the processed science image, meaning that the flat subtraction has worked.
